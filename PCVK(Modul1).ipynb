# %% [markdown]
# <a href="https://colab.research.google.com/github/PuputGaluh/pcvk_puput/blob/main/PCVK(Modul1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Langkah1 menggunakan beberapa library
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
#Langkah2 membaca dan menampilkan image
#Membuat list untuk menyimpan url dari beberapa image
urls = urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
               "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg"]
#baca dan tampilkan image
#loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url) #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) #convert color to RGB
  final_frame = cv.hconcat((image, image_2)) #concatenate image
  cv2_imshow(final_frame) #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
#Langkah3 melihat ukuran file image
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, "x", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286 x 400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
#Langkah4 mengakses pixel dengan memberi garis diagonal menyilang
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
#Tugas
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (tinggi):
  image_3[y, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_3, (0, 0), (lebar - 1, tinggi - 1), (255, 255, 255))
cv.line(image_3, (0, tinggi - 1), (lebar - 1, 0), (255, 255, 255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

panjang_garis = int(2 * 100 / 2.54)
posisi_awal = (lebar - panjang_garis) // 2 - 20

for x in range(posisi_awal, posisi_awal + panjang_garis):
    image_3[int(tinggi / 2), x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

panjang_garis = int(2 * 100 / 2.54)
posisi_awal_x = (lebar - panjang_garis) // 2 - 20
posisi_awal_y = (tinggi - panjang_garis) // 2

for x in range(posisi_awal_x, posisi_awal_x + panjang_garis):
    for y in range(posisi_awal_y, posisi_awal_y + panjang_garis):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
#Tugaskelompok
image = Image.open('bonbon.webp')
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
image = cv.imread('bonbon.webp')

image[180:200, 280:650] = (0, 255, 255)
image[120:150, 270:620] = (0, 255, 0)

plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# Pertanyaan
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab? Menurut saya Google Colab sangat cocok digunakan dalam pengolahan gambar.
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# - `import numpy as np`: opsional untuk fungsi array.
# - `import pandas as pd`: tidak digunakan, tidak ada data yang diproses.
# - `import cv2 as cv`: digunakan untuk pengolahan gambar.
# - `from google.colab.patches import cv2_imshow`: digunakan untuk menampilkan gambar.
# - `from skimage import io`: digunakan untuk mengambil gambar dari URL atau file.
# - `from skimage import transform`: opsional untuk mengubah ukuran gambar.
# - `from PIL import Image`: opsional, fungsi mirip dengan OpenCV.
# - `import matplotlib.pyplot as plt`: digunakan untuk visualisasi gambar.
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut : Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan? Kode tersebut berfungsi untuk mengubah ukuran gambar. Jika kode ini tidak ada, gambar akan tetap dengan ukuran aslinya dan tidak akan mengalami perubahan.
# 4. Perhatikan potongan kode progam berikut : Apakah kegunaan kode [255,255,255] ? Jelaskan! Kode tersebut akan mengubah warna garis menjadi putih.
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah! Semakin banyak pixel dalam sebuah gambar, maka resolusi gambar akan semakin tinggi. Gambar akan memiliki lebih banyak detail dan tampak lebih tajam. Sebaliknya, jika jumlah pixel semakin sedikit, resolusi gambar akan semakin rendah. Hal tersebut dapat menyebabkan gambar terlihat buram atau kurang jelas.
